# %% [markdown]
# <a href="https://colab.research.google.com/github/parthchoudhary237-jpg/python-basics-25bcon1095/blob/main/session4_25bcon1095.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n =5
fact = 1
for i in range(1, n +1):
  fact = fact* i
  print("factorial of ",n, "=", fact)

# %%
class Student:
    def _init_(self, name, roll, marks):
        self.name = name
        self.roll = roll
        self.marks = marks


s1 = Student("ADESH", 101, "60")

print("Name:", s1.name)
print("Roll:", s1.roll)
print("Marks:", s1.marks)

# %%
ef find_average(numbers):
    total = 0
    for i in range(len(numbers) - 1):
        total = total + numbers[i]
    return total / len(numbers)

result = find_average([10, 20, 30, 40])
print(result)
